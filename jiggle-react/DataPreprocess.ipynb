# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_excel('./public/data/articles.xlsx')

# %%
df = df.iloc[:16]

# %%
df
# Out:
#          매장 이름                     _x0008_주소
# 0        대충유원지          서울 마포구 월드컵북로6길 37 1층  \
# 1        대충유원지          서울 마포구 월드컵북로6길 37 1층
# 2        대충유원지          서울 마포구 월드컵북로6길 37 1층
# 3        스페이스깨  서울특별시 종로구 자하문로5길 15 스페이스깨 1층
# 4        하우스서울           서울 송파구 백제고분로9길 5 1층
# 5         주신당            서울 중구 퇴계로 411 1층 6호
# 6         아임뮤트          서울 강남구 논현로157길 36 1층
# 7           책바         서울 마포구 포은로 90 3층 301호
# 8   콩크 자재라이브러리            서울 마포구 양화로6길 50 3층
# 9         묘사서울             서울 성동구 서울숲2길 2 2층
# 10       TXT커피               서울 종로구 창덕궁길 121
# 11     플레이스1-3        서울 강남구 압구정로10길 21 4~6층
# 12          글월   서울 서대문구 증가로 10 연궁빌딩 4층 403호
# 13          글월   서울 서대문구 증가로 10 연궁빌딩 4층 403호
# 14     슈퍼말차 성수            서울 성동구 서울숲6길 19 1층
# 15        다이브인          서울 마포구 성미산로27길 67 3층
#
#                                                    링크                   비고
# 0                https://brunch.co.kr/@archive-zeze/6   같은 곳  ||  건축을 중심으로  \
# ...

# %%
df.to_excel('./public/data/articles_pre.xlsx')

# %%
df.to_csv('./public/data/Articles.csv', encoding='UTF-8')
